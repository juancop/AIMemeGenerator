# %%
import os

# %%
cwd = os.getcwd()

# %%
print("Current working directory: {0}".format(cwd))
# Out:
# Current working directory: C:\Users\jdmar\Documents\GitHub\CovidKnowledge\recursos\application_bootcamp

# %%
pip install -r requirements.txt
# Out:
# ...
#
# ...
#   Created wheel for dash: filename=dash-1.19.0-py3-none-any.whl size=84016 sha256=02480253b5923205dcd29274862c451e8499d052337ab98339c4c376ab662135
#   Stored in directory: c:\users\jdmar\appdata\local\pip\cache\wheels\e7\27\2f\a9f9bf858843b5365bcb311a80f0b2379737caf4ec50b2ae3a
# ...
#   Created wheel for dash-renderer: filename=dash_renderer-1.9.0-py3-none-any.whl size=1014874 sha256=972482b8aab09e30c3ab61e1127c3ea4bc609860dad8a09a44472108cb042b17
#   Stored in directory: c:\users\jdmar\appdata\local\pip\cache\wheels\08\94\09\e11ba8ae5d97e1c8ff5be0ac1f7cf42642eec6ea94ed1e4b44
# ...
#   Created wheel for dash-core-components: filename=dash_core_components-1.15.0-py3-none-any.whl size=3527018 sha256=bf78f2adc94d01488ccada159b7bfe8ee7477a63fa1a79232baa12e0fedb7f4f
#   Stored in directory: c:\users\jdmar\appdata\local\pip\cache\wheels\e3\e6\0e\759ca580c568aad2436521fa6df67f53a141dc1ab8f040c4c7
# ...

# %%
import main
# Out:
# Start process
# Error: no se puede cargar el archivo module 'os' has no attribute 'twitter_folder_path'
# Start Streaming
# RT @Mippcivzla: 📌𝙄𝙣𝙛𝙤́𝙧𝙢𝙖𝙩𝙚 🧬
#  La aparición de las variantes brasileras P1 y P2 aumenta el llamado a la conciencia de los venezolanos a man…
# Long: None, Lati: None
# Error inserting twitter:  local variable 'downloaded_tweets' referenced before assignment
# Working
# Cansada de jugar esto llamado, será alergia o covid? Ayudaaa
# Long: None, Lati: None
# Error inserting twitter:  local variable 'downloaded_tweets' referenced before assignment
# Working
# RT @CarlosA40128612: @Mippcivzla #24Mar 🇻🇪📢 ¡ETIQUETA DEL DÍA! ▶️ #PrevenirEsVencer
# @CarlosA40128612 @NicolasMaduro @Mippcivzla
#
#  Ante cual…
# Long: None, Lati: None
# Error inserting twitter:  local variable 'downloaded_tweets' referenced before assignment
# Working
# ...
